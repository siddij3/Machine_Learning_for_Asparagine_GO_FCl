# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split as tts
from random import seed
from random import random

seed(1)

#Initialization and organization of data
txt = open("data_banknote_authentication.txt").read().split('\n')
print(txt)
banknote = []

X_data = np.zeros((len(txt),4))
t_data = np.zeros(len(txt))

i = 0
for item in txt:
    banknote.append(item.split(','))    
    t_data[i] = banknote[i][4]  #The output value which is either 0 or 1
    del banknote[i][4]    
    i+=1
X_data = np.asarray(banknote)

#Splitting datasets
X_train, X_rem, t_train, t_rem = tts(X_data, t_data, train_size = 0.8, random_state = 5096)
X_valid, X_test, t_valid, t_test = tts(X_rem, t_rem, test_size=0.5)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test) 
X_valid = sc.transform(X_valid)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [1], in <module>
#       8 seed(1)
#      10 #Initialization and organization of data
# ---> 11 txt = open("data_banknote_authentication.txt").read().split('\n')
#      12 print(txt)
#      13 banknote = []
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data_banknote_authentication.txt'

# %%
# Initialize a network with 1 hidden layer
def initialize_network(n_inputs, n_hidden, n_outputs):
    network = list()
    
    #Puts in random weights for the connections in the hidden layer
    #Includes the weights plus the bias
    hidden_layer = np.zeros(( n_hidden, n_inputs + 1))
    for i in range(n_hidden):
        for j in range(n_inputs + 1):
            hidden_layer[i,j] = random()
                    

    network.append(hidden_layer)
    
    #Random weights to the output layer
    output_layer = np.zeros(( n_output, n_hidden + 1))
    for i in range(n_output):
        for j in range(n_hidden + 1):
            output_layer[i,j] = random()
 
    network.append(output_layer)
    
    return network

#ReLy activation for hidden layers
def ReLu(z):
    if (z.size == 1):
        if z <= 0:
            return 0   
    else:
        for i in range(len(z)):
            if z[i] <= 0:
                z[i] = 0
    return z

#Sigmoid activation for output layer
def sigmoid(z):    
    return  1/ (1.0 + np.exp(-z));

# Forward propagate input to the next network layer
def forward_propagate(network, example):
    #The added one is the bias weight
    inputs = np.copy(example)
    h_output = []
    #first is input, then hidden (possibly hidden again), then output
    i = 0
    for weights in network:
        
        inputs = np.append(1, inputs)
        
        z = weights @ inputs
        if ((network[-1][0, 1] == weights[0, 1])):
            h_output.append(sigmoid(z))
        else:
            h_output.append(ReLu(z))
        
        inputs = h_output[i]
        
        i += 1 
    return h_output #Becomes the input for the next

# %%
#Shuffles data at start of every training epoch
def shuffleData(X, t):
    assert X.shape[0] == len(t)
    p = np.random.permutation(len(t))
    return X[p], t[p]

#Computers the gradients of the weight vectors during back propogation for 1 hidden layer
def computeGradW_J_1hidden(network, h_outputs, X, t):
    delZ2_J = np.array([-t + h_outputs[-1]])   #(Computing Eq. 5 from Notes)
                        
    h1 = np.array([h_outputs[0]]).T
    
    #excluding the biases
    W2 = network[-1][0:, 1:].T
    W1 = network[0][0:, 1:].T

    delZ1_J = np.multiply(h1, W2) * delZ2_J  #(Computing Eq. 3 from Notes)

    X_1 = np.array([np.append(1, X)])
    h1_modified = np.array([np.append(1, h1.T[0])])

    gradW2J = delZ2_J @ h1_modified #(Computing Eq. 7 from Notes)
    gradW1J = delZ1_J @ X_1 #(Computing Eq. 2 from Notes)
    
    return [gradW1J, gradW2J]

#Update the weights using the gradients as shown in slide 23
def update_weights(network, old_network, gradW_J, alpha):
    for W in range(len(network)):
        network[W] = old_network[W] - alpha*gradW_J[W]
    return network

#Trains the network iterating through epochs and training values
def train_network(network, X, X_valid, t, t_valid, alpha, n_epoch, early_stopping, isN1N2):
    training_error = []
    validation_error = []
    
    min_training_error = 0
    
    lowest_weights_network = network
    
    for epoch in range(n_epoch):
        training_cross_entropy = 0
        validation_cross_entropy = 0

        f_x_w = np.zeros(X.shape[0])
        f_x_w_v = np.zeros(X_valid.shape[0])
        
        X, t = shuffleData(X, t)
        X_valid, t_valid = shuffleData(X_valid, t_valid)
    
        #For each epoch, forward propgate through every training example
        #Then evaluate the gradients
        #Perform back propogating, then update the weights
        for i in range(X.shape[0]):
            h_out = forward_propagate(network, X[i, :]) #The g(z) values output
            
            if (not isN1N2):
                gradW_J_all = computeGradW_J_1hidden(network, h_out, X[i, :], t[i])
            else: 
                gradW_J_all = computeGradW_J_2hidden(network, h_out, X[i, :], t[i])
                
            f_x_w[i] = h_out[-1]
            
            
            if (i < X_valid.shape[0]):
                h_out_v = forward_propagate(network, X_valid[i, :])
                f_x_w_v[i] = h_out_v[-1]
            
            
            old_network = network          
            network = update_weights(network, old_network, gradW_J_all, alpha)
            
        #Calucating and storign cross entropy losses
        training_cross_entropy =  -sum(t[0:] * np.log(f_x_w[0:]) + (1 - t[0:])*np.log(1 - f_x_w[0:])) / len(t)
        training_error.append(float(training_cross_entropy))
        
        
        validation_cross_entropy =  -sum(t_valid[0:] * np.log(f_x_w_v[0:]) +(1 - t_valid[0:])*np.log(1 - f_x_w_v[0:])) /len(t_valid) 
        validation_error.append(float(validation_cross_entropy))
        
        #Early stopping
        if (validation_cross_entropy <= min(validation_error)):
            min_validation_error = validation_cross_entropy
            lowest_weights_network = network
    
            
    return training_error, validation_error, n_epoch, lowest_weights_network
        #

# %%
n_input = 4
n_output = 1
alpha = 0.005
epochs = 100

early_stopping = 10

min_validation_errors = []
min_training_errors = []

all_networks  = []
all_validation_errors = []
all_training_errors = []

#Runs through 10 nodes for 1 hidden layer
for n_hidden in range (1, 11):
    
    network = initialize_network(n_input, n_hidden, n_output)
    training_error, validation_error, epochs, network = train_network(network, X_train, X_valid, t_train, t_valid, alpha, epochs, early_stopping, False)
        
    min_validation_errors.append(min(validation_error))
    min_training_errors.append(min(training_error))
    
    all_validation_errors.append(validation_error)
    all_training_errors.append(training_error)
    
    all_networks.append(network)
    
    #print(epochs)
    #print(len(training_error))


lowest_index = np.argmin(np.array(min_validation_errors))
print("N1 with the best performance is: " + str(lowest_index + 1))


print(min_training_errors)
print(min_validation_errors)

plt.scatter(range(0, epochs), all_training_errors[lowest_index], color = 'blue', label='training err')
plt.scatter(range(0, epochs), all_validation_errors[lowest_index], color = 'm', label='validation err')
plt.title('Cost function')
plt.legend()
plt.ylabel('cost')
plt.xlabel('iteration number')
plt.title('N Hidden: ' + str(lowest_index+1))
plt.show()
# Out:
# N1 with the best performance is: 9
# [0.02481688480268405, 0.02444049645588554, 0.006391428855970355, 0.006477276944524204, 0.007943796958430808, 0.001899625222004232, 0.0019423086907127108, 0.00888029929317058, 0.001670606304455417, 0.0032509792190016386]
# [0.022722977408298112, 0.022513909935307018, 0.006980393798488576, 0.007436632355709542, 0.008627875708942996, 0.0023914053946750913, 0.0023420271213366616, 0.009332797237056425, 0.002112839267789217, 0.00393357869292964]

# %%
#Computers the gradients of the weight vectors during back propogation for 2 hidden layers
def computeGradW_J_2hidden(network, h_outputs, X, t):
    delz3_J = np.array([-t + h_outputs[-1]])   #(Computing Eq. 5 from Notes)

    h2 = np.array([h_outputs[1]]).T
    h1 = np.array([h_outputs[0]]).T
   
    #excluding the biases
    W3_T = network[-1][0:, 1:].T
    W2_T = network[1][0:, 1:].T
    #W1_T = network[0][0:, 1:]
    
    delz2_J = np.multiply(h2, W3_T) * delz3_J
    delz1_J = np.multiply(h1, W2_T) @ delz2_J

    h1_modified = np.array([np.append(1, h1)])
    h2_modified = np.array([np.append(1, h2)])
    X_1 = np.array([np.append(1, X)])
   
    gradW3J = delz3_J * h2_modified
    gradW2J = delz2_J @ h1_modified #(Computing Eq. 7 from Notes)
    gradW1J = delz1_J @ X_1 #(Computing Eq. 2 from Notes)  
    
    return [gradW1J, gradW2J, gradW3J]

# Initialize a network with 2 hidden layers
def initialize_network_two(n_inputs, n1, n2, n_outputs):
    network = list()
    #Puts in random weights for the connections in the hidden layer
    #Includes the weights plus the bias
    hidden_n1 = np.zeros(( n1, n_inputs + 1))
    for i in range(n1):
        for j in range(n_inputs + 1):
            hidden_n1[i,j] = random()
                    
    #hidden_layer = [{'weights':[random() for i in range(n_inputs + 1)]} for i in range(n_hidden)]
    network.append(hidden_n1)
    
    #Random weights to the hidden 2 layer
    hidden_n2 = np.zeros(( n2, n1 + 1))
    for i in range(n2):
        for j in range(n1 + 1):
            hidden_n2[i,j] = random()
 
    network.append(hidden_n2)
    
        #Random weights to the output layer
    output_layer = np.zeros(( n_output, n2 + 1))
    for i in range(n_output):
        for j in range(n2 + 1):
            output_layer[i,j] = random()
 
    network.append(output_layer)
    
    return network

# %%
n_input = 4
n_output = 1
alpha = 0.005
epochs_v2=  50
early_stopping = 10

min_validation_errors_2 = []

all_networks_2_i  = []
all_validation_errors_2_i = [] 
all_training_errors_2_i = []

lowest_n1_n2 = np.ones((10, 10))
lowest_training = np.ones((10, 10))

#Runs through 10 nodes sum of n1 and n2 for 2 hidden layer
for i in range(1, 10):
    all_networks_2_j  = []
    all_validation_errors_2_j = [] 
    all_training_errors_2_j = []
    for j in range(1, 10):
        if (i+j > 10):
            continue
 
        network_2 = initialize_network_two(n_input, i, j, n_output)
        training_error_n2, validation_error_n2, epochs_v2, network_v2 = train_network(network_2, X_train, X_valid, t_train, t_valid, alpha, epochs, early_stopping, True)
           
        lowest_training[i,j] = min(training_error_n2)
        lowest_n1_n2[i, j] = min(validation_error_n2)
        
        #Adding all the errors to a list to pull out the optimal training and validation error, and the optimal network
        all_validation_errors_2_j.append(validation_error_n2)
        all_training_errors_2_j.append(training_error_n2)
        all_networks_2_j.append(network_v2)
    
    all_validation_errors_2_i.append(all_validation_errors_2_j)
    all_training_errors_2_i.append(all_training_errors_2_j)
    all_networks_2_i.append(all_networks_2_j)



#Find the indexes with the lowest validation error
lowest_indexes_tmp = np.amin(lowest_n1_n2, axis=-1, keepdims=True)

result = np.where(lowest_n1_n2 == min((lowest_indexes_tmp))[0])
lowest_n1 = result[0][0]
lowest_n2 = result[1][0]


plt.scatter(range(0, epochs), all_training_errors_2_i[lowest_n1-1][lowest_n2-1], color = 'blue', label='training err')
plt.scatter(range(0, epochs), all_validation_errors_2_i[lowest_n1-1][lowest_n2-1], color = 'm', label='validation err')
plt.title('Cost function')
plt.legend()
plt.ylabel('cost')
plt.xlabel('Epoch number')
plt.title('N1: ' + str(lowest_n1) +  " & N2: " + str(lowest_n2))
plt.show()
# Out:
# C:\Users\junai\AppData\Local\Temp\ipykernel_11196\3725376792.py:73: RuntimeWarning: divide by zero encountered in log
#   training_cross_entropy =  -sum(t[0:] * np.log(f_x_w[0:]) + (1 - t[0:])*np.log(1 - f_x_w[0:])) / len(t)
# C:\Users\junai\AppData\Local\Temp\ipykernel_11196\3725376792.py:73: RuntimeWarning: invalid value encountered in multiply
#   training_cross_entropy =  -sum(t[0:] * np.log(f_x_w[0:]) + (1 - t[0:])*np.log(1 - f_x_w[0:])) / len(t)
# C:\Users\junai\AppData\Local\Temp\ipykernel_11196\3725376792.py:77: RuntimeWarning: divide by zero encountered in log
#   validation_cross_entropy =  -sum(t_valid[0:] * np.log(f_x_w_v[0:]) +(1 - t_valid[0:])*np.log(1 - f_x_w_v[0:])) /len(t_valid)
# C:\Users\junai\AppData\Local\Temp\ipykernel_11196\3725376792.py:77: RuntimeWarning: invalid value encountered in multiply
#   validation_cross_entropy =  -sum(t_valid[0:] * np.log(f_x_w_v[0:]) +(1 - t_valid[0:])*np.log(1 - f_x_w_v[0:])) /len(t_valid)
# [[1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]
#  [1.00000000e+00 2.54044683e-02 2.89583677e-02 3.43400311e-02
#   3.43027105e-02 3.10689452e-02 3.26101631e-02 3.23807242e-02
#   2.63533790e-02 2.82120375e-02]
#  [1.00000000e+00 4.27887727e-03 1.21276651e-02 1.41417671e-02
#   2.06286371e-02 3.45953322e-02 7.92125052e-03 2.85133907e-02
#   1.25569925e-02 1.00000000e+00]
#  [1.00000000e+00 1.59689907e-02 8.39030861e-03 1.20068457e-02
#   8.61959960e-03 1.27986004e-02 5.30527766e-03 1.36235877e-02
#   1.00000000e+00 1.00000000e+00]
#  [1.00000000e+00 1.75416908e-02 1.43272434e-02 1.07582139e-02
#   2.19576759e-02 6.26014534e-03 1.46814867e-03 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]
#  [1.00000000e+00 9.53051929e-03 6.60274917e-03 8.50428795e-03
#   5.38040338e-03 1.17775801e-02 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]
#  [1.00000000e+00 2.28229148e-03 1.24724067e-02 1.36145510e-03
#   8.66910569e-03 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]
#  [1.00000000e+00 8.13543790e-03 4.48332328e-04 8.83194526e-03
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]
#  [1.00000000e+00 1.30050732e-02 1.89957946e-03 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]
#  [1.00000000e+00 2.79230314e-03 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]]
# [[1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]
#  [1.00000000e+00 1.23774541e-02 3.07559313e-02 3.83169197e-02
#   4.16243683e-02 2.96071614e-02 3.44248210e-02 4.55769783e-02
#   1.57904333e-02 2.97850529e-02]
#  [1.00000000e+00 3.70391731e-03 1.14963926e-02 9.21502803e-03
#   3.14469009e-02 4.09422115e-02 6.70385946e-03 3.65372686e-02
#   1.01962164e-02 1.00000000e+00]
#  [1.00000000e+00 1.81741640e-02 8.31406501e-03 1.08006834e-02
#   5.86771193e-03 5.86721015e-03 1.91477814e-03 1.25952225e-02
#   1.00000000e+00 1.00000000e+00]
#  [1.00000000e+00 1.31449986e-02 7.22316266e-03 8.78330801e-03
#   3.72050360e-02 9.39641902e-03 1.06255892e-03 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]
#  [1.00000000e+00 9.10380022e-03 8.37963534e-03 7.41579990e-03
#   3.12055290e-03 6.04070879e-03 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]
#  [1.00000000e+00 2.24128534e-03 1.03364452e-02 1.74668495e-03
#   9.31774746e-03 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]
#  [1.00000000e+00 7.30138096e-03 9.46975260e-05 5.93360040e-03
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]
#  [1.00000000e+00 9.47302557e-03 1.90430356e-03 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]
#  [1.00000000e+00 2.49131981e-03 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]]

# %%
#Misclassification Errors using test set
def computeTestError(network, X, t):
    
    test_cross_entropy = 0
    
    f_x_w_t = np.zeros(X.shape[0])

    X, t = shuffleData(X, t)

    for i in range(X.shape[0]):
        h_out_t = forward_propagate(network, X[i, :]) #The g(z) values output
    
        f_x_w_t[i] = h_out_t[-1]

    test_cross_entropy =  -sum(t[0:] * np.log(f_x_w_t[0:]) + (1 - t[0:])*np.log(1 - f_x_w_t[0:])) / len(t)
    return test_cross_entropy

#Assign best network, then computes cross entropy error with the test set
best_one_layer_network = all_networks[lowest_index]
best_two_layer_network = all_networks_2_i[lowest_n1-1][lowest_n2-1]

test_error_one_layer = computeTestError(best_one_layer_network, X_test, t_test)
test_error_two_layers = computeTestError(network, X_test, t_test)

# %%
print(test_error_one_layer)
print(test_error_two_layers)
# Out:
# 0.0009062955519519596
# 0.0038740286134529636
